# %%
# Victor Z and David Cole
# UW-Madison, 2024
# pdf and cdf of a Poisson RV

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Parameters
lambda_vals = [1/2, 5, 10]
colors = ["black", "black", "black"]
markers = ["o-", "x-", "d-"]

x = np.arange(0, 21)

# Generate realizations
S = 1000
np.random.seed(0)
X = poisson.rvs(1/2, size=S)

# %%
# Plotting
plt.figure(figsize=(10, 8))

# Subplot 1: Realizations
plt.subplot(2, 2, (1, 2))
plt.plot(X, 'ko', markerfacecolor='w', markersize=4)
plt.xlabel('Outcome $\\omega$', fontsize=14)
plt.ylabel('$x_\\omega$', fontsize=14)
plt.grid(True)
plt.yticks(np.arange(0, 16, 1))
plt.axis([0, S, 0, 10])

# Subplot 2: PDF
plt.subplot(2, 2, 3)
for k, lam in enumerate(lambda_vals):
    plt.plot(x, poisson.pmf(x, lam), markers[k], markerfacecolor='w', markeredgecolor=colors[k], color=colors[k], label=f'$\\lambda={lam}$')
plt.grid(True)
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$f(x)$', fontsize=14)
plt.legend(loc='upper right', fontsize=12)

# Subplot 3: CDF
plt.subplot(2, 2, 4)
for k, lam in enumerate(lambda_vals):
    plt.plot(x, poisson.cdf(x, lam), markers[k], markerfacecolor='w', markeredgecolor=colors[k], color=colors[k], label=f'$\\lambda={lam}$')
plt.grid(True)
plt.xlabel('$x$', fontsize=14)
plt.ylabel('$F(x)$', fontsize=14)

plt.tight_layout()
plt.show()
