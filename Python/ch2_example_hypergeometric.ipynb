# %%
# Victor Z and David Cole
# UW-Madison, 2024
# example hypergeometric

# %%
import numpy as np
from scipy.stats import hypergeom

# model parameters
np.random.seed(0)
N = 156  # total number of times in 3 years (population)
Nd = 79  # total number of failures in 3 years
p = Nd / N

# %%
# case with 5 inspection times
n = 5  # number of times inspected

# probability that 5 out of 5 times it has failed
x = n
P = hypergeom.pmf(x, N, Nd, n)
print(f"Probability that {x} out of {n} times it has failed: {P}")
# Out:
# Probability that 5 out of 5 times it has failed: 0.03123023402909551

# %%
# probability that 0 out of 5 times it has failed
x = 0
P = hypergeom.pmf(x, N, Nd, n)
print(f"Probability that {x} out of {n} times it has failed: {P}")
# Out:
# Probability that 0 out of 5 times it has failed: 0.027378403801553704

# %%
# case with 10 inspection times
n = 10  # number of times inspected

# probability that 10 out of 10 times it has failed
x = n
P = hypergeom.pmf(x, N, Nd, n)
print(f"Probability that {x} out of {n} times it has failed: {P}")
# Out:
# Probability that 10 out of 10 times it has failed: 0.0008222145897166328

# %%
# probability that 0 out of 10 times it has failed
x = 0
P = hypergeom.pmf(x, N, Nd, n)
print(f"Probability that {x} out of {n} times it has failed: {P}")
# Out:
# Probability that 0 out of 10 times it has failed: 0.0006260679738640766
